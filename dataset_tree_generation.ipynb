# %%
import numpy as np
import pandas as pd
import os
import shutil

# %% [markdown]
# ## Read the dataset csv

# %%
folder_path = "data/scene_castle"
files = []
for i in os.listdir(folder_path):
    if os.path.isfile(os.path.join(folder_path,i)) and 'dataset' in i:
        files.append(i)

dataset = pd.read_csv(os.path.join(folder_path, files[0]))
dataset.head()
# Out:
#                      scene  illuminant  scene_center_x  scene_center_y  \
# 0  BP_Castle01202012111252      2500.0     -288.643311    -4780.570313
# 1  BP_Castle01202012111252      3500.0     -288.643311    -4780.570313
# 2  BP_Castle01202012111252      4500.0     -288.643311    -4780.570313
# 3  BP_Castle01202012111252      5500.0     -288.643311    -4780.570313
# 4  BP_Castle01202012111252      6500.0     -288.643311    -4780.570313
#
#    scene_center_z rendered_image  camera_location_x  camera_location_y  \
# 0     1435.449219     image0.png        -494.628357       -4455.423828
# 1     1435.449219     image1.png        -494.628357       -4455.423828
# 2     1435.449219     image2.png        -494.628357       -4455.423828
# 3     1435.449219     image3.png        -494.628357       -4455.423828
# 4     1435.449219     image4.png        -494.628357       -4455.423828
#
#    camera_location_z  NW  N  NE  E  SE  S  SW  W  white_balance  \
# 0        1508.005981   1  0   0  0   0  0   0  0         6500.0
# 1        1508.005981   1  0   0  0   0  0   0  0         6500.0
# 2        1508.005981   1  0   0  0   0  0   0  0         6500.0
# 3        1508.005981   1  0   0  0   0  0   0  0         6500.0
# 4        1508.005981   1  0   0  0   0  0   0  0         6500.0
#
#    exposure_compensation pointlight_intensity
# 0                    0.0   421.177826Candelas
# 1                    0.0   421.177826Candelas
# 2                    0.0   421.177826Candelas
# 3                    0.0   421.177826Candelas
# 4                    0.0   421.177826Candelas

# %% [markdown]
# ## Creating the folders for the classifying

# %%
color_temperatures = [2500 + 1000*k for k in range(5)]
locations = {'NW', 'N', 'NE', 'E', 'SE', 'S', 'SW', 'W'}

for temperature in color_temperatures:
    temperature_path = os.path.join(folder_path, str(temperature))
    os.mkdir(temperature_path)
    for location in locations:
        os.mkdir(os.path.join(temperature_path, location))

# %% [markdown]
# ## Creating dataset for each illuminant and move the files accordingly

# %%
for temperature in color_temperatures:
    for location in locations:
        condition = (dataset[location] == 1) & (dataset['illuminant'] == temperature) 
        dataset[condition].to_csv(os.path.join(folder_path, str(temperature), location, 'dataset_'+str(temperature)+'_'+location+'.csv'))
        for index, row in dataset[condition].iterrows():
            image_name = row['rendered_image'].split('.')[0]
            for i in os.listdir(folder_path):
                if os.path.isfile(os.path.join(folder_path,i)) and (image_name == i.split('_')[0] or image_name == i.split('.')[0]):
                    file_path = os.path.join(folder_path, i)
                    new_path = os.path.join(folder_path, str(temperature), location, i)
                    shutil.move(file_path, new_path)

# %% [markdown]
# ## The folders are now ready for ML!
